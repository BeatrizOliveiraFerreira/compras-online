# %% [markdown]
# # Pessoas que compram

# %%
# Importando matplotlib
import matplotlib.pyplot as plt

# Criando nosso conjunto de dados
labels = 'Moda', 'Telefonia','Primeira vez online'
sizes = [13300.000,2900.000, 22800.000,]

# Estamos criando a representação, área de plotagem
fig1, ax1 = plt.subplots(figsize=(6, 6))

# Criando o gráfico
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)

# Com esta opção, o gráfico ficará em círculo
ax1.axis('equal')

# Mostra o gráfico
plt.show()

# %% [markdown]
# # FONTES
# # Onde eu tirei as fontes de compras: https://www.ecommercebrasil.com.br/noticias/primeiro-trimestre-de-2021-vendas-alta-de-57/#:~:text=Foram%20realizadas%2078%2C5%20milh%C3%B5es,2%25%20na%20compara%C3%A7%C3%A3o%20com%202020.
#
# # Gráficos de pizza com matplotlib:
# https://medium.com/horadecodar/gr%C3%A1ficos-de-pizza-com-matplotlib-piechart-33ea9760ad87
